# %%
import pandas as pd

# %%
df1 = pd.read_csv('./../Dataset/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', low_memory=False)

# %%
df2 = pd.read_csv('./../Dataset/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv',low_memory=False)
df3 = pd.read_csv('./../Dataset/Friday-WorkingHours-Morning.pcap_ISCX.csv',low_memory=False)
df4 = pd.read_csv('./../Dataset/Monday-WorkingHours.pcap_ISCX.csv',low_memory=False)
df5 = pd.read_csv('./../Dataset/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv',low_memory=False)
df6 = pd.read_csv('./../Dataset/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv',low_memory=False)
df7 = pd.read_csv('./../Dataset/Tuesday-WorkingHours.pcap_ISCX.csv',low_memory=False)
df8 = pd.read_csv('./../Dataset/Wednesday-workingHours.pcap_ISCX.csv',low_memory=False)

# %%
Frames = [df1,df2,df3,df4,df5,df6,df7,df8]
DF = pd.concat(Frames)

# %%
DF.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count       2.830743e+06    2.830743e+06        2.830743e+06
# mean        8.071483e+03    1.478566e+07        9.361160e+00
# std         1.828363e+04    3.365374e+07        7.496728e+02
# min         0.000000e+00   -1.300000e+01        1.000000e+00
# 25%         5.300000e+01    1.550000e+02        2.000000e+00
# 50%         8.000000e+01    3.131600e+04        2.000000e+00
# 75%         4.430000e+02    3.204828e+06        5.000000e+00
# max         6.553500e+04    1.200000e+08        2.197590e+05
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count             2.830743e+06                 2.830743e+06
# mean              1.039377e+01                 5.493024e+02
# std               9.973883e+02                 9.993589e+03
# min               0.000000e+00                 0.000000e+00
# 25%               1.000000e+00                 1.200000e+01
# ...

# %%
DF.to_pickle("./DF.pkl")
